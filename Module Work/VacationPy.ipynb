# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("cities.csv")
city_data_df.head()
# Out:
#    City_ID     City Country                 Date      Lat       Lng  Max Temp  \
# 0        0     Tura      IN  2021-07-11 08:21:06  25.5198   90.2201     78.10
# 1        1   Noumea      NC  2021-07-11 08:21:06 -22.2763  166.4572     71.01
# 2        2   Narsaq      GL  2021-07-11 08:21:07  60.9167  -46.0500     46.62
# 3        3    Praya      CV  2021-07-11 08:21:08  14.9215  -23.5087     73.94
# 4        4  Mataura      NZ  2021-07-11 08:21:08 -46.1927  168.8643     39.92
#
#    Humidity  Cloudiness  Wind Speed
# 0        93         100        2.82
# 1        99          90       14.67
# 2        84         100        4.54
# 3        73          75        6.91
# 4        96          97        2.62

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = [max(temp, 0) for temp in max_temp]

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 60
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 0         0            Tura      IN  2021-07-11 08:21:06  25.5198   90.2201
# 1         1          Noumea      NC  2021-07-11 08:21:06 -22.2763  166.4572
# 3         3           Praya      CV  2021-07-11 08:21:08  14.9215  -23.5087
# 5         5       Jamestown      US  2021-07-11 08:21:08  42.0970  -79.2353
# 7         7      Butaritari      KI  2021-07-11 08:21:09   3.0707  172.7902
# 8         8  Saint-Philippe      RE  2021-07-11 08:21:09 -21.3585   55.7679
# 11       11      Morant Bay      JM  2021-07-11 08:21:10  17.8815  -76.4093
# 12       12        Hamilton      US  2021-07-11 08:21:10  39.1834  -84.5333
# 13       13         Bacolod      PH  2021-07-11 08:19:40  10.6667  122.9500
# 14       14        Lorengau      PG  2021-07-11 08:21:10  -2.0226  147.2712
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 0      78.10        93         100        2.82
# 1      71.01        99          90       14.67
# 3      73.94        73          75        6.91
# 5      62.24        95          40        1.99
# 7      82.98        72          84       13.33
# 8      77.22        78          46       15.82
# 11     80.22        84          14       10.38
# 12     71.98        95          20        1.01
# 13     85.39        77          88        4.65
# 14     81.16        83         100        8.61

# %%
preferred_cities_df.count()
# Out:
# City_ID       398
# City          398
# Country       395
# Date          398
# Lat           398
# Lng           398
# Max Temp      398
# Humidity      398
# Cloudiness    398
# Wind Speed    398
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#          City Country  Max Temp      Lat       Lng Hotel Name
# 0        Tura      IN     78.10  25.5198   90.2201
# 1      Noumea      NC     71.01 -22.2763  166.4572
# 3       Praya      CV     73.94  14.9215  -23.5087
# 5   Jamestown      US     62.24  42.0970  -79.2353
# 7  Butaritari      KI     82.98   3.0707  172.7902

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
   
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
len(hotels["results"])
hotels
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEDfrLsKJ1FxuNwTzDk6ZdvQOpQtGALQQcyldJlTxdqm1CJZsSyltEUCbTBrBa1pNfHtIFUwqajr3yZ13_hltiR8_y0Yv7yco8wT7FrL-ShpydxKIbLV2KWQ7A5g0tHjHlCiWkio_Nce7mAT2tRnukMojHOt0_lg-CK30Aj7CQQ9S2Ff_6VyOM_3znI5xPB1DKTHFl0y6TCl_dkudVfBeftVEEATEH8p7LjHh7ymmjwMaWSPwk_IrTgOaKScFzr1T4BXeTnvw-XEsJW8lR-3O7u61UmXjOdEqHKpwkP_fkIN4tk8tGNk7HjEzu2Jd3r2nxBmA-opJnSKwINo9GSIOCh10GeUStj3sjnkeKbVLQrCylpPxfkKVsp9FuMVjy01mmjaFx-fsr7uWndel773BvS_uKAKqIfa1U4YXL2gLNdF7_32Wyg1bYcX',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.6529397, 'lng': -51.9976615},
#     'viewport': {'northeast': {'lat': -6.651564319708497,
#       'lng': -51.9962097197085},
#      'southwest': {'lat': -6.654262280291501, 'lng': -51.9989076802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Rio Xingu Camping',
#    'photos': [{'height': 2250,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118227862655758901585">Cledson mendonça</a>'],
#      'photo_reference': 'Aap_uEChn4V21z1NOHc39KlB2iDS75LgheBmZNJqRSDcY5eIWy00v68z3OYpTBbAjyLQ7pTjFdigLZAziNL6rUtkdt7eh5YN4YmwXvnPscVY_TEcap0qtqFx-yYeTxU0i2I3izF79-c4QO7mrWWwwyBZoxJ7bMJHlVPbj-wxZEZ0kk_iTxmG',
#      'width': 3843}],
#    'place_id': 'ChIJDYDzY0Cq5ZIRzx59W_oEFtk',
#    'plus_code': {'compound_code': '82W2+RW São Félix do Xingu, PA, Brazil',
#     'global_code': '685C82W2+RW'},
#    'rating': 4.4,
#    'reference': 'ChIJDYDzY0Cq5ZIRzx59W_oEFtk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 27,
#    'vicinity': 'Rua Dois, Lote 01 - Sol Poente, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.640848999999998, 'lng': -51.9828226},
#     'viewport': {'northeast': {'lat': -6.639606869708496,
#       'lng': -51.9814783197085},
#      'southwest': {'lat': -6.642304830291501, 'lng': -51.9841762802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Apart Hotel Rio Xingu',
#    'photos': [{'height': 2250,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118227862655758901585">Cledson mendonça</a>'],
#      'photo_reference': 'Aap_uECAeoTvP0B-ggBnWasW-eK1hEDkxq-7xmLiqK3XrP9W2fe4emvL8htRF-xkd1nXz9wDFndNwngQJqMjBVvYKCdd6fVgxo_AnFcQGZEJ4fzoN51i-Qbg802YLEln13e-9h6ezjMsnC82ZzLVCc0imYRY6PYvqSY41449j9b3b7gP1rQt',
#      'width': 4000}],
#    'place_id': 'ChIJTXVakS2q5ZIRKLVmRpoeGvg',
#    'plus_code': {'compound_code': '9258+MV São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9258+MV'},
#    'rating': 3.9,
#    'reference': 'ChIJTXVakS2q5ZIRKLVmRpoeGvg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 118,
#    'vicinity': 'Avenida Rio Xingu, 2113, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.642894, 'lng': -51.993576},
#     'viewport': {'northeast': {'lat': -6.641599269708498,
#       'lng': -51.9921775197085},
#      'southwest': {'lat': -6.644297230291502, 'lng': -51.9948754802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Terraço Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117900107842461915879">Terraço Hotel</a>'],
#      'photo_reference': 'Aap_uEBG52SYoMQV2qSm-wXX-0zJlf2ovYsEepcPaDqFBz1tFlvvLcCqUC8ybTTsOE2YMzGc7HgF_ANyYgFl0giHVgj4ObcPVPqTVvV8IxS11b18cLRcIVXcx-Tbc6IBEws8SmC26WF0Vg8qfGOeTtTkS0tNiHkxfOMRyQME6o2c8LtQvq2C',
#      'width': 4032}],
#    'place_id': 'ChIJkYusNTuq5ZIRuFbO2v_QJ2s',
#    'plus_code': {'compound_code': '9244+RH São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9244+RH'},
#    'rating': 3.9,
#    'reference': 'ChIJkYusNTuq5ZIRuFbO2v_QJ2s',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 103,
#    'vicinity': '605, Avenida Antônio Marquês Ribeiro, 286 - Centro, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.642415199999998,
#      'lng': -51.99400219999999},
#     'viewport': {'northeast': {'lat': -6.641020869708496,
#       'lng': -51.9926948197085},
#      'southwest': {'lat': -6.6437188302915, 'lng': -51.9953927802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Carajas',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117072471870042077340">juliano mendes</a>'],
#      'photo_reference': 'Aap_uEC3IfZ7-xFdEub-QbrztYhQNpP-C4ygoPzg_jS4PdfQe34kYRM2gG-_r2-agH0l9k6OCZSzgq2n4NT4LDH7VhFCYiO2T9L3ofo_Us_p-qBh3VFajzW-u9TwAuYYQQdKYsMsmpEKlwUyxCqYxsC2sTAF7bVkuBwgs_z40KoEvhHmg8nI',
#      'width': 1920}],
#    'place_id': 'ChIJG5JxyiSq5ZIRmbznG24qLiw',
#    'plus_code': {'compound_code': '9254+29 São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9254+29'},
#    'rating': 3.8,
#    'reference': 'ChIJG5JxyiSq5ZIRmbznG24qLiw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 123,
#    'vicinity': 'Avenida 22 de Março, 934 - Centro, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.642204800000001, 'lng': -51.9938204},
#     'viewport': {'northeast': {'lat': -6.640824769708499,
#       'lng': -51.99249791970851},
#      'southwest': {'lat': -6.643522730291503, 'lng': -51.9951958802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Xingu',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114386144590569997758">Juan Azevedo</a>'],
#      'photo_reference': 'Aap_uED_ci_y4E0sjtnFfEBNA69cup-eYiaC1Jpvx1_Hwe3X7i9EuYO9yFjoFOPp1fx70MXyZyO1ARnQMioGSU3DsGyz0FVU3zEHloIqyRPTdWVDTG5hVj3Ad2yuspxnRIIyfltHhKIfiyPQ0SGCRqMO4HBkSo3niWePeXjfdOCEfAxrZezP',
#      'width': 1920}],
#    'place_id': 'ChIJSfpdyC2r5ZIRD31RgfU2-Fo',
#    'plus_code': {'compound_code': '9254+4F São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9254+4F'},
#    'rating': 4.2,
#    'reference': 'ChIJSfpdyC2r5ZIRD31RgfU2-Fo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.642152500000001, 'lng': -51.9927886},
#     'viewport': {'northeast': {'lat': -6.640864169708498,
#       'lng': -51.9913835697085},
#      'southwest': {'lat': -6.643562130291502, 'lng': -51.9940815302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Triste hotel',
#    'place_id': 'ChIJT-TxVMmr5ZIRGH716a-DMKA',
#    'plus_code': {'compound_code': '9254+4V São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9254+4V'},
#    'rating': 5,
#    'reference': 'ChIJT-TxVMmr5ZIRGH716a-DMKA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Avenida Antônio Marquês Ribeiro, 1009 - Centro, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.642112500000001, 'lng': -51.9927512},
#     'viewport': {'northeast': {'lat': -6.640727169708499,
#       'lng': -51.99136171970851},
#      'southwest': {'lat': -6.643425130291503, 'lng': -51.99405968029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Eldorado',
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107062061653617545682">Leandro Amorim Da Silva</a>'],
#      'photo_reference': 'Aap_uEDBpoHr_ygIH2PMNsTrEl0-L1v-R_ku-ssXrvQlnhyDG39X1pbwmdSiMGkmgr65LE1-wgeeOZX4yNzpUJK0g1mQMTeXMov1kXmCD7yuFHiNb0CErOBZidMf9LOq_xhCWBsZJp42Fp5viTifD-FFOiNHj3YWU-SZY4VL-NBXWoPW-F7N',
#      'width': 2560}],
#    'place_id': 'ChIJLZD_1iSq5ZIRZvDALkfy60c',
#    'plus_code': {'compound_code': '9254+5V São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9254+5V'},
#    'rating': 4,
#    'reference': 'ChIJLZD_1iSq5ZIRZvDALkfy60c',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 19,
#    'vicinity': 'Rua Fernando Guilhon, 188 - Centro, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.6477996, 'lng': -51.9971052},
#     'viewport': {'northeast': {'lat': -6.646387419708497,
#       'lng': -51.9958358697085},
#      'southwest': {'lat': -6.649085380291502, 'lng': -51.9985338302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Beira Rio',
#    'photos': [{'height': 9248,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103316530338273618317">Hotel Beira Rio</a>'],
#      'photo_reference': 'Aap_uEAMy7_BOlsigcRWcDI3le4mn0msKsdgWgQq0us4G6PRNXeGoWBOAMem8Qmv_sVzn9DYUOC6PSztyxuMVR9sgaxSBlJ6Z_IB6_1BvLuoFOSYVUEOWZNdrypzdovvo-cqW91Ad3HbkPY5DHuZEU9ZlW8viVL8Sld4y2UbJ49GqqqgUfOM',
#      'width': 6936}],
#    'place_id': 'ChIJreFVuR6r5ZIRc-IogAdfocQ',
#    'plus_code': {'compound_code': '9223+V5 São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9223+V5'},
#    'rating': 5,
#    'reference': 'ChIJreFVuR6r5ZIRc-IogAdfocQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Avenida Presidente Castelo Branco - Solar das águas, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.6411684, 'lng': -51.99342050000001},
#     'viewport': {'northeast': {'lat': -6.639817619708498,
#       'lng': -51.9920697197085},
#      'southwest': {'lat': -6.642515580291501, 'lng': -51.99476768029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Casa Comando',
#    'place_id': 'ChIJV_SGTU-r5ZIREvzGH5FOjVU',
#    'plus_code': {'compound_code': '9254+GJ São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9254+GJ'},
#    'rating': 4.3,
#    'reference': 'ChIJV_SGTU-r5ZIREvzGH5FOjVU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Travessa Fernando Guilhon, 168-246, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.648447000000001, 'lng': -51.9931519},
#     'viewport': {'northeast': {'lat': -6.647048719708498,
#       'lng': -51.99191286970851},
#      'southwest': {'lat': -6.649746680291503, 'lng': -51.99461083029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Vista Rara',
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108180273002518885011">Força Foco Fé</a>'],
#      'photo_reference': 'Aap_uEA6a5WLE8ZPohbyOw36z-bIX8XjE4rLrzOGpUjcgJorLlgDvK3KNKkP5ojRvrH4OWQC01l_Rgumlpb90Zb66lOLYb3c-J8O18VYVfT8EvNuAmoPRTBAxtjapURycsumKX7Q9gUOcuWD-wIs8F8amyDSglkv1-O3Ve9lgyc8UplwZ5_G',
#      'width': 4128}],
#    'place_id': 'ChIJoVU0EDmq5ZIR4bvN_RbeLzI',
#    'plus_code': {'compound_code': '9224+JP São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9224+JP'},
#    'rating': 4.1,
#    'reference': 'ChIJoVU0EDmq5ZIR4bvN_RbeLzI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 49,
#    'vicinity': 'Avenida Das Palmeiras, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.640802400000001, 'lng': -51.9925263},
#     'viewport': {'northeast': {'lat': -6.639496019708497,
#       'lng': -51.9911358197085},
#      'southwest': {'lat': -6.642193980291502, 'lng': -51.9938337802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Rio Xingu',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108726468738535524894">Clédson Mendonça Júnior</a>'],
#      'photo_reference': 'Aap_uEBblY81nCNbTLvfXvTeduB62AK4GnWMdtNEaWXGthjM3z6vXB1MlWnA0oQtnCZRO9pCukK1dJe5D2hYOpUde42TaLyzxVG4hkzdcWR3ijmbGFSIRi9PMvSesHe6SOqnis3cqJXiVu5NpZPjk_FClA0e7EqspYnNgjMHPVFuCilmzjuB',
#      'width': 4608}],
#    'place_id': 'ChIJXRGkoyWq5ZIRNB9TYWKnZsk',
#    'plus_code': {'compound_code': '9254+MX São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9254+MX'},
#    'rating': 4,
#    'reference': 'ChIJXRGkoyWq5ZIRNB9TYWKnZsk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 74,
#    'vicinity': 'Avenida 22 de Março, 1159 - Centro, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.640886299999999,
#      'lng': -51.99222290000001},
#     'viewport': {'northeast': {'lat': -6.639566769708497,
#       'lng': -51.99091006970851},
#      'southwest': {'lat': -6.642264730291502, 'lng': -51.9936080302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Jacaré Palace Hotel',
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116638980567517984800">Lady Andrea Carvalho</a>'],
#      'photo_reference': 'Aap_uEC7HRTaG6VFcQmcyRONhvSnCv3vhm73PhS-rn7yMXsDxQ9v9DNT98w_cvuvAR-jv60Sm6WDzIO_Q3vrGoVojfr1Rw2-V99oKvdsiRhML9oiFXVLlvYUC5sLZ6hbfVNz4ILoYcc3XXyzwO2avmQSDl1zHC6xlTCFGpx_Die51NLuGyP7',
#      'width': 2560}],
#    'place_id': 'ChIJjcoFViSq5ZIRepBk5-UyyNU',
#    'plus_code': {'compound_code': '9255+J4 São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9255+J4'},
#    'rating': 4,
#    'reference': 'ChIJjcoFViSq5ZIRepBk5-UyyNU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 83,
#    'vicinity': 'Travessa Manoel Antônio dos Santos, 187 - Centro, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.641021699999999,
#      'lng': -51.99144279999999},
#     'viewport': {'northeast': {'lat': -6.639705869708497,
#       'lng': -51.99006396970849},
#      'southwest': {'lat': -6.642403830291502, 'lng': -51.99276193029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Diplomata',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109392946171681096736">Hotel Diplomata</a>'],
#      'photo_reference': 'Aap_uEBbdSQS_TSy6V79wn0Roljtiio2XSb-bETIw7SiQ1hX2Cp2JUx34O_WLmiJnQdvfx0ZXiN6tpKqBz4yKJ1iZJo6UhHWRBphbiLMQHkoab9yPHmBtfI50J0dbUr2NYSjupP_okTEx-SPraNHXlW6wWXMCCEnaMDUN42rfxtIbE_yf1aD',
#      'width': 2960}],
#    'place_id': 'ChIJh-SYEyWq5ZIR2zINbN64-g8',
#    'plus_code': {'compound_code': '9255+HC São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9255+HC'},
#    'rating': 3.5,
#    'reference': 'ChIJh-SYEyWq5ZIR2zINbN64-g8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': 'Avenida Antônio Marquês Ribeiro, 1193 - Centro, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.648047500000001, 'lng': -52.0003237},
#     'viewport': {'northeast': {'lat': -6.646669669708499,
#       'lng': -51.99898741970851},
#      'southwest': {'lat': -6.649367630291503, 'lng': -52.00168538029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Rancho Bessa de Sá',
#    'place_id': 'ChIJDwl_L66r5ZIRoa1SszN9c0g',
#    'plus_code': {'compound_code': '9X2X+QV São Félix do Xingu, PA, Brazil',
#     'global_code': '68599X2X+QV'},
#    'rating': 5,
#    'reference': 'ChIJDwl_L66r5ZIRoa1SszN9c0g',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Avenida Coronel Tancredo, 993, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.6390004, 'lng': -51.9903949},
#     'viewport': {'northeast': {'lat': -6.637709969708498,
#       'lng': -51.9890483697085},
#      'southwest': {'lat': -6.640407930291502, 'lng': -51.9917463302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pousada Figueiredo',
#    'place_id': 'ChIJ91FS8yWq5ZIRq1SNy9kuuVk',
#    'plus_code': {'compound_code': '9265+9R São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9265+9R'},
#    'rating': 3.9,
#    'reference': 'ChIJ91FS8yWq5ZIRq1SNy9kuuVk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 16,
#    'vicinity': 'Avenida Piauí, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.63822, 'lng': -51.99059609999999},
#     'viewport': {'northeast': {'lat': -6.636968669708497,
#       'lng': -51.9892569697085},
#      'southwest': {'lat': -6.639666630291502, 'lng': -51.9919549302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pousada Santos',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 958,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101050294672912567962">Pousada Santos</a>'],
#      'photo_reference': 'Aap_uEB8-9aUMJhxTjd1zYCjc9BR6uTqr1RWhPZXgbKbvE4rudoMZC902ueUs4szkozkg3RaZiWmA8T1SVmU7IRkn1ztvXBQBC_pzTrzCk6WTnTSHRnLMSBFsQUxMP3gRTNKGlTORYm0SUTJCOB2baMjJjQg47p18aAheC7j95JN2hvtO2P-',
#      'width': 1280}],
#    'place_id': 'ChIJW39W4iWq5ZIRL09GVsBhy9k',
#    'plus_code': {'compound_code': '9265+PQ São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9265+PQ'},
#    'rating': 3.6,
#    'reference': 'ChIJW39W4iWq5ZIRL09GVsBhy9k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 20,
#    'vicinity': 'Avenida Ceará, N°241, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.6382583, 'lng': -51.98985},
#     'viewport': {'northeast': {'lat': -6.637017169708498,
#       'lng': -51.9885064697085},
#      'southwest': {'lat': -6.639715130291503, 'lng': -51.9912044302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Dormitorio Do Totó',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115414453351072684170">JOÃO MARCOS</a>'],
#      'photo_reference': 'Aap_uEBz7rBM1YrK6NnWLZHcyBcbp3l5YdhCh3SQSYse-ZlBd5rwRKE1EVQLU0suiXgnE4Nnszgdf4kP8gMq7AWDB-KxikrC3QUFRnZhLwJk4NfiNAeLNsNpZyeSfJC6RbPOEwWASmZ3Ie5fFBsHn9HbM_Bg2TlwpfSxUwyEjdMiXqVDljyx',
#      'width': 1280}],
#    'place_id': 'ChIJN0u_-CWq5ZIRFRlruEgDSKY',
#    'plus_code': {'compound_code': '9266+M3 São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9266+M3'},
#    'rating': 1,
#    'reference': 'ChIJN0u_-CWq5ZIRFRlruEgDSKY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Avenida Ceará, 287-413, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.6399592, 'lng': -51.9875297},
#     'viewport': {'northeast': {'lat': -6.638630869708498,
#       'lng': -51.9861818197085},
#      'southwest': {'lat': -6.641328830291503, 'lng': -51.9888797802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Bringel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2340,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102938557812391256331">INC73 Força Nacional</a>'],
#      'photo_reference': 'Aap_uECS7-arJCR3huOmAzp9B4XRU47pLhcum-rsIWZRgwy0iIK0BoWjbo1sGVV9lr2SovZ-nHS7csNupjuTvCtE7r31Djry5exLPvAOgeeiZ5jjNLBEUsvIuKEmP1eoVmhMXQnQUb4ORPOcIVXNsojqUgnady7hVZU-dVEMz9J7TXnsAB5y',
#      'width': 4160}],
#    'place_id': 'ChIJG9eFVXur5ZIRfykkkXXz8Mg',
#    'plus_code': {'compound_code': '9266+2X São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9266+2X'},
#    'rating': 5,
#    'reference': 'ChIJG9eFVXur5ZIRfykkkXXz8Mg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.638154799999999, 'lng': -51.9889264},
#     'viewport': {'northeast': {'lat': -6.636803719708497,
#       'lng': -51.9876494197085},
#      'southwest': {'lat': -6.639501680291501, 'lng': -51.9903473802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Pontal',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 384,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114109303628409437795">Leticia Silva E Silva</a>'],
#      'photo_reference': 'Aap_uEAQ8WSOvpvSPSJ8oGFU6iP67yky3TnqgBOLYzAIdk3ynTE3QUUFxDF27XDGSsp-rrJkiRLrcGGE0r5S5N1DiU_2GhK5sXtVuGkUgnmv2_xPSgcPu2ylNKk8S4krxzfEW1WQAElcgXacEVGNEx72CQ1SG9iOREf_MRVF-1SsItJmwbz1',
#      'width': 384}],
#    'place_id': 'ChIJcxKGTi-q5ZIRP49cYvfzt-8',
#    'plus_code': {'compound_code': '9266+PC São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9266+PC'},
#    'rating': 3.4,
#    'reference': 'ChIJcxKGTi-q5ZIRP49cYvfzt-8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 29,
#    'vicinity': 'Rua Osório de Oliveira Freitas, 658-734, São Félix do Xingu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.6362479, 'lng': -51.99127350000001},
#     'viewport': {'northeast': {'lat': -6.634898669708497,
#       'lng': -51.98995621970851},
#      'southwest': {'lat': -6.637596630291502, 'lng': -51.99265418029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Salinas Exclusive Resort',
#    'place_id': 'ChIJDxIJSSaq5ZIR9CGnGoOXIzM',
#    'plus_code': {'compound_code': '9275+GF São Félix do Xingu, PA, Brazil',
#     'global_code': '685C9275+GF'},
#    'reference': 'ChIJDxIJSSaq5ZIR9CGnGoOXIzM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Rua 16 de novembro Número 35, São Félix do Xingu'}],
#  'status': 'OK'}

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
