# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

from datetime import datetime
from citipy import citipy
from config import weather_api_key

# %% [markdown]
# ### STEP 3 - Create 2,000 random latitudes and longitudes

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %% [markdown]
# ### STEP 4 - Nearest City

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %% [markdown]
# ### STEP 5 - API Call

# %%
#API CALL
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Make a 'Get' request for the city weather.
city_weather = requests.get(url)

# %% [markdown]
# ### STEP 6 - Retrieve

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description= city_weather["weather"][0]["description"]
            # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mehamn
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | fujin
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | narsaq
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | lisakovsk
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | ziro
# Processing Record 12 of Set 1 | vila franca do campo
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | nanortalik
# Processing Record 15 of Set 1 | ternate
# Processing Record 16 of Set 1 | belyy yar
# Processing Record 17 of Set 1 | pangnirtung
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | brae
# Processing Record 20 of Set 1 | lagoa
# Processing Record 21 of Set 1 | hay river
# Processing Record 22 of Set 1 | yambio
# Processing Record 23 of Set 1 | kaitangata
# Processing Record 24 of Set 1 | high level
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | severo-kurilsk
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | vuktyl
# Processing Record 32 of Set 1 | egvekinot
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | basingstoke
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | praia da vitoria
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | ardistan
# City not found. Skipping...
# Processing Record 40 of Set 1 | kamaishi
# Processing Record 41 of Set 1 | avera
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | mount gambier
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | mattru
# Processing Record 46 of Set 1 | leningradskiy
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | san felipe
# Processing Record 49 of Set 1 | zyryanka
# Processing Record 50 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | wajima
# Processing Record 5 of Set 2 | jinotega
# Processing Record 6 of Set 2 | kyrylivka
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | leh
# Processing Record 9 of Set 2 | sawakin
# Processing Record 10 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | bukama
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | sayyan
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 2 | luanda
# Processing Record 17 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 2 | mahebourg
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | hede
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 23 of Set 2 | cap malheureux
# Processing Record 24 of Set 2 | talnakh
# Processing Record 25 of Set 2 | kruisfontein
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | ostrovnoy
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | camacha
# Processing Record 31 of Set 2 | touros
# Processing Record 32 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 2 | manitouwadge
# Processing Record 34 of Set 2 | dengfeng
# Processing Record 35 of Set 2 | san quintin
# Processing Record 36 of Set 2 | mataura
# Processing Record 37 of Set 2 | pevek
# Processing Record 38 of Set 2 | naze
# Processing Record 39 of Set 2 | lagoa vermelha
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | wakkanai
# Processing Record 44 of Set 2 | benguela
# Processing Record 45 of Set 2 | vestmannaeyjar
# Processing Record 46 of Set 2 | sitka
# Processing Record 47 of Set 2 | sotnikovo
# Processing Record 48 of Set 2 | nome
# Processing Record 49 of Set 2 | alyangula
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | quatre cocos
# Processing Record 3 of Set 3 | itarema
# Processing Record 4 of Set 3 | souillac
# Processing Record 5 of Set 3 | pontivy
# Processing Record 6 of Set 3 | nea makri
# Processing Record 7 of Set 3 | castro
# Processing Record 8 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 3 | kearney
# Processing Record 10 of Set 3 | saint-francois
# Processing Record 11 of Set 3 | buraydah
# Processing Record 12 of Set 3 | lakes entrance
# Processing Record 13 of Set 3 | yar-sale
# Processing Record 14 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 3 | tongliao
# Processing Record 16 of Set 3 | yulara
# Processing Record 17 of Set 3 | puerto del rosario
# Processing Record 18 of Set 3 | pacific grove
# Processing Record 19 of Set 3 | parabel
# Processing Record 20 of Set 3 | colares
# Processing Record 21 of Set 3 | cabo san lucas
# Processing Record 22 of Set 3 | emerald
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | hiriyur
# Processing Record 25 of Set 3 | barrow
# Processing Record 26 of Set 3 | kavaratti
# Processing Record 27 of Set 3 | saint-pascal
# City not found. Skipping...
# Processing Record 28 of Set 3 | salamanca
# Processing Record 29 of Set 3 | hanna
# Processing Record 30 of Set 3 | arraial do cabo
# Processing Record 31 of Set 3 | derzhavinsk
# Processing Record 32 of Set 3 | omsukchan
# Processing Record 33 of Set 3 | awbari
# Processing Record 34 of Set 3 | honningsvag
# Processing Record 35 of Set 3 | lima
# Processing Record 36 of Set 3 | port elizabeth
# Processing Record 37 of Set 3 | sao filipe
# Processing Record 38 of Set 3 | tala
# Processing Record 39 of Set 3 | klaksvik
# Processing Record 40 of Set 3 | mosquera
# Processing Record 41 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 3 | marawi
# Processing Record 43 of Set 3 | erzurum
# Processing Record 44 of Set 3 | hasaki
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | concordia
# Processing Record 47 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 3 | bethel
# Processing Record 49 of Set 3 | iskateley
# Processing Record 50 of Set 3 | xam nua
# Processing Record 1 of Set 4 | acari
# Processing Record 2 of Set 4 | prince albert
# Processing Record 3 of Set 4 | formosa do rio preto
# Processing Record 4 of Set 4 | lodja
# Processing Record 5 of Set 4 | vallenar
# Processing Record 6 of Set 4 | muravlenko
# Processing Record 7 of Set 4 | kasungu
# Processing Record 8 of Set 4 | grindavik
# Processing Record 9 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 4 | staryy nadym
# Processing Record 11 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 4 | almaznyy
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | coos bay
# Processing Record 15 of Set 4 | illapel
# Processing Record 16 of Set 4 | saint-augustin
# Processing Record 17 of Set 4 | carnarvon
# Processing Record 18 of Set 4 | port alfred
# Processing Record 19 of Set 4 | saldanha
# Processing Record 20 of Set 4 | semey
# Processing Record 21 of Set 4 | lorengau
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | cidreira
# Processing Record 24 of Set 4 | saint-pierre
# Processing Record 25 of Set 4 | herat
# Processing Record 26 of Set 4 | hithadhoo
# Processing Record 27 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 4 | kholodnyy
# Processing Record 29 of Set 4 | sibenik
# Processing Record 30 of Set 4 | muros
# Processing Record 31 of Set 4 | tasiilaq
# Processing Record 32 of Set 4 | mandera
# Processing Record 33 of Set 4 | berbera
# Processing Record 34 of Set 4 | shimoda
# Processing Record 35 of Set 4 | thongwa
# Processing Record 36 of Set 4 | geraldton
# Processing Record 37 of Set 4 | kununurra
# Processing Record 38 of Set 4 | wattegama
# Processing Record 39 of Set 4 | tabuk
# Processing Record 40 of Set 4 | lodwar
# Processing Record 41 of Set 4 | broome
# Processing Record 42 of Set 4 | chokurdakh
# Processing Record 43 of Set 4 | huaicheng
# Processing Record 44 of Set 4 | yangjiang
# Processing Record 45 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 4 | tambul
# City not found. Skipping...
# Processing Record 47 of Set 4 | waipawa
# Processing Record 48 of Set 4 | zhigansk
# Processing Record 49 of Set 4 | slave lake
# Processing Record 50 of Set 4 | qinhuangdao
# Processing Record 1 of Set 5 | nanakuli
# Processing Record 2 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 3 of Set 5 | tessalit
# Processing Record 4 of Set 5 | ust-barguzin
# Processing Record 5 of Set 5 | gorontalo
# Processing Record 6 of Set 5 | vardo
# Processing Record 7 of Set 5 | albanel
# Processing Record 8 of Set 5 | hualmay
# Processing Record 9 of Set 5 | hambantota
# Processing Record 10 of Set 5 | gerash
# Processing Record 11 of Set 5 | ponta do sol
# Processing Record 12 of Set 5 | lake charles
# Processing Record 13 of Set 5 | kindu
# Processing Record 14 of Set 5 | mar del plata
# Processing Record 15 of Set 5 | iqaluit
# Processing Record 16 of Set 5 | wagga wagga
# Processing Record 17 of Set 5 | aripuana
# Processing Record 18 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 19 of Set 5 | hilo
# Processing Record 20 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 5 | kasra
# City not found. Skipping...
# Processing Record 22 of Set 5 | bonavista
# Processing Record 23 of Set 5 | dudinka
# Processing Record 24 of Set 5 | vao
# Processing Record 25 of Set 5 | vestmanna
# Processing Record 26 of Set 5 | upernavik
# Processing Record 27 of Set 5 | shache
# Processing Record 28 of Set 5 | camacari
# Processing Record 29 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 5 | longyearbyen
# Processing Record 31 of Set 5 | tawang
# Processing Record 32 of Set 5 | cacoal
# Processing Record 33 of Set 5 | portland
# Processing Record 34 of Set 5 | baykit
# Processing Record 35 of Set 5 | maniitsoq
# Processing Record 36 of Set 5 | puerto ayora
# Processing Record 37 of Set 5 | marrakesh
# Processing Record 38 of Set 5 | waingapu
# Processing Record 39 of Set 5 | jalu
# Processing Record 40 of Set 5 | fereydun kenar
# Processing Record 41 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 5 | wiang sa
# Processing Record 43 of Set 5 | rio gallegos
# Processing Record 44 of Set 5 | volsk
# Processing Record 45 of Set 5 | tabory
# Processing Record 46 of Set 5 | hays
# Processing Record 47 of Set 5 | provideniya
# Processing Record 48 of Set 5 | changchun
# Processing Record 49 of Set 5 | los llanos de aridane
# Processing Record 50 of Set 5 | aykhal
# Processing Record 1 of Set 6 | teguise
# Processing Record 2 of Set 6 | nivala
# Processing Record 3 of Set 6 | ancud
# Processing Record 4 of Set 6 | port hardy
# Processing Record 5 of Set 6 | clyde river
# Processing Record 6 of Set 6 | tiarei
# Processing Record 7 of Set 6 | belmonte
# Processing Record 8 of Set 6 | mumford
# Processing Record 9 of Set 6 | bumba
# Processing Record 10 of Set 6 | namatanai
# Processing Record 11 of Set 6 | satka
# Processing Record 12 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 6 | bambous virieux
# Processing Record 14 of Set 6 | beloha
# Processing Record 15 of Set 6 | matagami
# Processing Record 16 of Set 6 | manggar
# Processing Record 17 of Set 6 | dawei
# Processing Record 18 of Set 6 | bara
# Processing Record 19 of Set 6 | rocha
# Processing Record 20 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 6 | bosaso
# Processing Record 22 of Set 6 | arlington
# Processing Record 23 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 6 | tiksi
# Processing Record 25 of Set 6 | pangody
# Processing Record 26 of Set 6 | vila velha
# Processing Record 27 of Set 6 | cheremnoye
# Processing Record 28 of Set 6 | comodoro rivadavia
# Processing Record 29 of Set 6 | bilibino
# Processing Record 30 of Set 6 | sao sebastiao do paraiso
# Processing Record 31 of Set 6 | santa cruz
# Processing Record 32 of Set 6 | sovetskiy
# Processing Record 33 of Set 6 | matara
# Processing Record 34 of Set 6 | ravar
# Processing Record 35 of Set 6 | bengkulu
# Processing Record 36 of Set 6 | asau
# Processing Record 37 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 6 | flin flon
# Processing Record 39 of Set 6 | mayo
# Processing Record 40 of Set 6 | yurimaguas
# Processing Record 41 of Set 6 | oga
# Processing Record 42 of Set 6 | murray
# Processing Record 43 of Set 6 | grand-bourg
# Processing Record 44 of Set 6 | uppsala
# Processing Record 45 of Set 6 | ustyuzhna
# Processing Record 46 of Set 6 | kumano
# Processing Record 47 of Set 6 | porto novo
# Processing Record 48 of Set 6 | korla
# Processing Record 49 of Set 6 | kudahuvadhoo
# Processing Record 50 of Set 6 | adoni
# Processing Record 1 of Set 7 | copiapo
# Processing Record 2 of Set 7 | tateyama
# Processing Record 3 of Set 7 | wajir
# Processing Record 4 of Set 7 | muisne
# Processing Record 5 of Set 7 | saint george
# Processing Record 6 of Set 7 | chenghai
# Processing Record 7 of Set 7 | luderitz
# Processing Record 8 of Set 7 | conde
# Processing Record 9 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 7 | birjand
# Processing Record 11 of Set 7 | lasa
# Processing Record 12 of Set 7 | hervey bay
# Processing Record 13 of Set 7 | begunitsy
# Processing Record 14 of Set 7 | suzano
# Processing Record 15 of Set 7 | san patricio
# Processing Record 16 of Set 7 | mindelo
# Processing Record 17 of Set 7 | shimabara
# Processing Record 18 of Set 7 | lala
# Processing Record 19 of Set 7 | terre haute
# Processing Record 20 of Set 7 | catamarca
# Processing Record 21 of Set 7 | isangel
# Processing Record 22 of Set 7 | francistown
# Processing Record 23 of Set 7 | te anau
# Processing Record 24 of Set 7 | port lincoln
# Processing Record 25 of Set 7 | toora-khem
# Processing Record 26 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 27 of Set 7 | alofi
# Processing Record 28 of Set 7 | bathsheba
# Processing Record 29 of Set 7 | saint-joseph
# Processing Record 30 of Set 7 | faanui
# Processing Record 31 of Set 7 | byron bay
# Processing Record 32 of Set 7 | bayji
# Processing Record 33 of Set 7 | athol
# Processing Record 34 of Set 7 | lebu
# Processing Record 35 of Set 7 | lethem
# Processing Record 36 of Set 7 | emba
# Processing Record 37 of Set 7 | port hedland
# Processing Record 38 of Set 7 | dwarka
# Processing Record 39 of Set 7 | bogovarovo
# Processing Record 40 of Set 7 | sinjar
# Processing Record 41 of Set 7 | nouakchott
# Processing Record 42 of Set 7 | la tuque
# Processing Record 43 of Set 7 | yining
# Processing Record 44 of Set 7 | wanaka
# Processing Record 45 of Set 7 | newport
# Processing Record 46 of Set 7 | walvis bay
# Processing Record 47 of Set 7 | kahului
# Processing Record 48 of Set 7 | kenai
# Processing Record 49 of Set 7 | pangkalanbuun
# Processing Record 50 of Set 7 | pasighat
# Processing Record 1 of Set 8 | ahipara
# Processing Record 2 of Set 8 | honiara
# Processing Record 3 of Set 8 | maumere
# Processing Record 4 of Set 8 | metehara
# City not found. Skipping...
# Processing Record 5 of Set 8 | srednekolymsk
# Processing Record 6 of Set 8 | kitimat
# Processing Record 7 of Set 8 | esperance
# Processing Record 8 of Set 8 | san cristobal
# Processing Record 9 of Set 8 | shunyi
# Processing Record 10 of Set 8 | ust-omchug
# Processing Record 11 of Set 8 | lompoc
# Processing Record 12 of Set 8 | manzhouli
# Processing Record 13 of Set 8 | hornostayivka
# Processing Record 14 of Set 8 | kostomuksha
# Processing Record 15 of Set 8 | winsum
# Processing Record 16 of Set 8 | lavrentiya
# Processing Record 17 of Set 8 | sahbuz
# Processing Record 18 of Set 8 | ugoofaaru
# Processing Record 19 of Set 8 | ilulissat
# Processing Record 20 of Set 8 | rawah
# Processing Record 21 of Set 8 | barabash
# Processing Record 22 of Set 8 | kasane
# Processing Record 23 of Set 8 | machilipatnam
# Processing Record 24 of Set 8 | bururi
# Processing Record 25 of Set 8 | daugai
# Processing Record 26 of Set 8 | mount darwin
# Processing Record 27 of Set 8 | oytal
# Processing Record 28 of Set 8 | ostersund
# Processing Record 29 of Set 8 | anadyr
# Processing Record 30 of Set 8 | ballina
# Processing Record 31 of Set 8 | cleethorpes
# Processing Record 32 of Set 8 | batemans bay
# Processing Record 33 of Set 8 | formosa
# Processing Record 34 of Set 8 | san policarpo
# Processing Record 35 of Set 8 | bowen
# Processing Record 36 of Set 8 | cherskiy
# Processing Record 37 of Set 8 | chicama
# Processing Record 38 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 39 of Set 8 | koumra
# Processing Record 40 of Set 8 | nambucca heads
# Processing Record 41 of Set 8 | antofagasta
# Processing Record 42 of Set 8 | nanzhang
# Processing Record 43 of Set 8 | airai
# Processing Record 44 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 45 of Set 8 | katsuura
# Processing Record 46 of Set 8 | mareeba
# Processing Record 47 of Set 8 | pacifica
# Processing Record 48 of Set 8 | puerto gaitan
# Processing Record 49 of Set 8 | chipinge
# Processing Record 50 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 9 | deputatskiy
# Processing Record 2 of Set 9 | birin
# Processing Record 3 of Set 9 | constitucion
# Processing Record 4 of Set 9 | momcilgrad
# City not found. Skipping...
# Processing Record 5 of Set 9 | trapani
# Processing Record 6 of Set 9 | katherine
# Processing Record 7 of Set 9 | arica
# Processing Record 8 of Set 9 | dzilam gonzalez
# Processing Record 9 of Set 9 | coihaique
# Processing Record 10 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 9 | balabac
# Processing Record 12 of Set 9 | olafsvik
# Processing Record 13 of Set 9 | taoudenni
# Processing Record 14 of Set 9 | kitakyushu
# Processing Record 15 of Set 9 | si bun ruang
# Processing Record 16 of Set 9 | dhidhdhoo
# Processing Record 17 of Set 9 | valle de allende
# Processing Record 18 of Set 9 | amritsar
# Processing Record 19 of Set 9 | trairi
# Processing Record 20 of Set 9 | burnie
# Processing Record 21 of Set 9 | kutum
# Processing Record 22 of Set 9 | port moresby
# Processing Record 23 of Set 9 | alta floresta
# Processing Record 24 of Set 9 | winnemucca
# Processing Record 25 of Set 9 | karratha
# Processing Record 26 of Set 9 | bahia blanca
# Processing Record 27 of Set 9 | baculin
# Processing Record 28 of Set 9 | margate
# Processing Record 29 of Set 9 | pahrump
# Processing Record 30 of Set 9 | akureyri
# Processing Record 31 of Set 9 | carauari
# Processing Record 32 of Set 9 | omboue
# Processing Record 33 of Set 9 | vohibinany
# Processing Record 34 of Set 9 | saint-jean-port-joli
# Processing Record 35 of Set 9 | eirunepe
# Processing Record 36 of Set 9 | hamilton
# Processing Record 37 of Set 9 | amantea
# Processing Record 38 of Set 9 | sechura
# Processing Record 39 of Set 9 | ust-uda
# Processing Record 40 of Set 9 | iztapa
# Processing Record 41 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 9 | melendugno
# Processing Record 43 of Set 9 | warrnambool
# Processing Record 44 of Set 9 | usinsk
# Processing Record 45 of Set 9 | port blair
# Processing Record 46 of Set 9 | fandriana
# Processing Record 47 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 48 of Set 9 | yerbogachen
# Processing Record 49 of Set 9 | port keats
# Processing Record 50 of Set 9 | birnin kebbi
# Processing Record 1 of Set 10 | manta
# Processing Record 2 of Set 10 | hellvik
# Processing Record 3 of Set 10 | balakhta
# Processing Record 4 of Set 10 | husavik
# Processing Record 5 of Set 10 | balykshi
# Processing Record 6 of Set 10 | matay
# Processing Record 7 of Set 10 | coquimbo
# Processing Record 8 of Set 10 | rabo de peixe
# Processing Record 9 of Set 10 | nago
# Processing Record 10 of Set 10 | mahon
# Processing Record 11 of Set 10 | dingle
# Processing Record 12 of Set 10 | zhuhai
# Processing Record 13 of Set 10 | point fortin
# Processing Record 14 of Set 10 | richards bay
# Processing Record 15 of Set 10 | sao gabriel da cachoeira
# Processing Record 16 of Set 10 | adrar
# Processing Record 17 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 18 of Set 10 | codrington
# Processing Record 19 of Set 10 | sept-iles
# Processing Record 20 of Set 10 | arco
# Processing Record 21 of Set 10 | leshukonskoye
# Processing Record 22 of Set 10 | zhangye
# Processing Record 23 of Set 10 | miguel auza
# Processing Record 24 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 10 | wonthaggi
# Processing Record 26 of Set 10 | rantepao
# Processing Record 27 of Set 10 | ketchikan
# Processing Record 28 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 29 of Set 10 | mokrousovo
# Processing Record 30 of Set 10 | paamiut
# Processing Record 31 of Set 10 | dargaville
# Processing Record 32 of Set 10 | jiwani
# Processing Record 33 of Set 10 | mabaruma
# Processing Record 34 of Set 10 | xining
# Processing Record 35 of Set 10 | nalut
# Processing Record 36 of Set 10 | cayenne
# Processing Record 37 of Set 10 | santa teresa
# Processing Record 38 of Set 10 | padang
# Processing Record 39 of Set 10 | tandalti
# Processing Record 40 of Set 10 | kitaibaraki
# Processing Record 41 of Set 10 | shingu
# Processing Record 42 of Set 10 | ayagoz
# Processing Record 43 of Set 10 | chapais
# Processing Record 44 of Set 10 | umm lajj
# Processing Record 45 of Set 10 | takoradi
# Processing Record 46 of Set 10 | monduli
# Processing Record 47 of Set 10 | smithers
# Processing Record 48 of Set 10 | cocentaina
# Processing Record 49 of Set 10 | drawsko pomorskie
# Processing Record 50 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 11 | muli
# Processing Record 2 of Set 11 | baft
# Processing Record 3 of Set 11 | bakel
# Processing Record 4 of Set 11 | gamba
# Processing Record 5 of Set 11 | blyth
# Processing Record 6 of Set 11 | palmer
# Processing Record 7 of Set 11 | orissaare
# Processing Record 8 of Set 11 | sao joao da barra
# Processing Record 9 of Set 11 | chernyshevskiy
# Processing Record 10 of Set 11 | speightstown
# Processing Record 11 of Set 11 | qandala
# Processing Record 12 of Set 11 | billings
# Processing Record 13 of Set 11 | boatlaname
# City not found. Skipping...
# Processing Record 14 of Set 11 | delijan
# Processing Record 15 of Set 11 | maningrida
# Processing Record 16 of Set 11 | suntar
# Processing Record 17 of Set 11 | oranjemund
# Processing Record 18 of Set 11 | sorland
# Processing Record 19 of Set 11 | glendive
# Processing Record 20 of Set 11 | karasjok
# Processing Record 21 of Set 11 | balkanabat
# Processing Record 22 of Set 11 | baruun-urt
# Processing Record 23 of Set 11 | dauriya
# Processing Record 24 of Set 11 | roebourne
# Processing Record 25 of Set 11 | martapura
# Processing Record 26 of Set 11 | irece
# Processing Record 27 of Set 11 | miyako
# Processing Record 28 of Set 11 | melville
# Processing Record 29 of Set 11 | gejiu
# Processing Record 30 of Set 11 | ramos arizpe
# Processing Record 31 of Set 11 | chumikan
# Processing Record 32 of Set 11 | sayat
# Processing Record 33 of Set 11 | romulus
# Processing Record 34 of Set 11 | porto nacional
# Processing Record 35 of Set 11 | nizwa
# Processing Record 36 of Set 11 | mansa
# Processing Record 37 of Set 11 | petatlan
# Processing Record 38 of Set 11 | thinadhoo
# Processing Record 39 of Set 11 | estelle
# Processing Record 40 of Set 11 | kavieng
# Processing Record 41 of Set 11 | mount isa
# Processing Record 42 of Set 11 | syedove
# Processing Record 43 of Set 11 | khuzhir
# Processing Record 44 of Set 11 | storforshei
# Processing Record 45 of Set 11 | the valley
# Processing Record 46 of Set 11 | kasongo-lunda
# Processing Record 47 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 48 of Set 11 | nortelandia
# Processing Record 49 of Set 11 | nabire
# Processing Record 50 of Set 11 | pundaguitan
# Processing Record 1 of Set 12 | crib point
# Processing Record 2 of Set 12 | tabas
# Processing Record 3 of Set 12 | el sauzal
# Processing Record 4 of Set 12 | chapayevka
# Processing Record 5 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 6 of Set 12 | port said
# Processing Record 7 of Set 12 | yeppoon
# Processing Record 8 of Set 12 | micheweni
# Processing Record 9 of Set 12 | kalia
# Processing Record 10 of Set 12 | henties bay
# Processing Record 11 of Set 12 | roald
# Processing Record 12 of Set 12 | loknya
# Processing Record 13 of Set 12 | armidale
# Processing Record 14 of Set 12 | cabedelo
# Processing Record 15 of Set 12 | lubango
# Processing Record 16 of Set 12 | kamenka
# Processing Record 17 of Set 12 | presidencia roque saenz pena
# Processing Record 18 of Set 12 | nouadhibou
# Processing Record 19 of Set 12 | salinopolis
# Processing Record 20 of Set 12 | terrace
# Processing Record 21 of Set 12 | bend
# Processing Record 22 of Set 12 | sindor
# Processing Record 23 of Set 12 | qorveh
# Processing Record 24 of Set 12 | grand-lahou
# Processing Record 25 of Set 12 | pueblo rico
# Processing Record 26 of Set 12 | yefira
# City not found. Skipping...
# Processing Record 27 of Set 12 | kampot
# Processing Record 28 of Set 12 | hirara
# Processing Record 29 of Set 12 | kimbe
# Processing Record 30 of Set 12 | kailua
# Processing Record 31 of Set 12 | gazanjyk
# Processing Record 32 of Set 12 | kudchi
# City not found. Skipping...
# Processing Record 33 of Set 12 | tres lagoas
# Processing Record 34 of Set 12 | mvuma
# Processing Record 35 of Set 12 | miguel alves
# Processing Record 36 of Set 12 | channel-port aux basques
# Processing Record 37 of Set 12 | bandarbeyla
# Processing Record 38 of Set 12 | fairbanks
# Processing Record 39 of Set 12 | tinskoy
# Processing Record 40 of Set 12 | bubaque
# Processing Record 41 of Set 12 | morondava
# Processing Record 42 of Set 12 | suwanee
# Processing Record 43 of Set 12 | kuryk
# Processing Record 44 of Set 12 | kirakira
# Processing Record 45 of Set 12 | sawtell
# Processing Record 46 of Set 12 | garowe
# Processing Record 47 of Set 12 | teguldet
# Processing Record 48 of Set 12 | amapa
# Processing Record 49 of Set 12 | miri
# Processing Record 50 of Set 12 | maple creek
# Processing Record 1 of Set 13 | acapulco
# Processing Record 2 of Set 13 | bose
# Processing Record 3 of Set 13 | mezen
# Processing Record 4 of Set 13 | arawa
# Processing Record 5 of Set 13 | kazerun
# Processing Record 6 of Set 13 | lumsden
# Processing Record 7 of Set 13 | batangafo
# Processing Record 8 of Set 13 | caravelas
# Processing Record 9 of Set 13 | eyl
# Processing Record 10 of Set 13 | shu
# Processing Record 11 of Set 13 | botwood
# Processing Record 12 of Set 13 | kinkala
# Processing Record 13 of Set 13 | dubti
# Processing Record 14 of Set 13 | amberieu-en-bugey
# Processing Record 15 of Set 13 | itapolis
# Processing Record 16 of Set 13 | north bend
# Processing Record 17 of Set 13 | campos
# Processing Record 18 of Set 13 | mackenzie
# Processing Record 19 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 13 | belle glade
# Processing Record 21 of Set 13 | burica
# City not found. Skipping...
# Processing Record 22 of Set 13 | kourou
# Processing Record 23 of Set 13 | bemban
# Processing Record 24 of Set 13 | kuching
# Processing Record 25 of Set 13 | tilichiki
# Processing Record 26 of Set 13 | biak
# Processing Record 27 of Set 13 | rajamahendri
# City not found. Skipping...
# Processing Record 28 of Set 13 | jiazi
# Processing Record 29 of Set 13 | rudbar
# Processing Record 30 of Set 13 | gossaigaon
# Processing Record 31 of Set 13 | verkhniy ufaley
# Processing Record 32 of Set 13 | mayna
# Processing Record 33 of Set 13 | lago da pedra
# Processing Record 34 of Set 13 | meulaboh
# Processing Record 35 of Set 13 | rudnogorsk
# Processing Record 36 of Set 13 | hobyo
# Processing Record 37 of Set 13 | bacungan
# Processing Record 38 of Set 13 | sayabec
# City not found. Skipping...
# Processing Record 39 of Set 13 | manaure
# Processing Record 40 of Set 13 | mishkino
# Processing Record 41 of Set 13 | sao paulo do potengi
# Processing Record 42 of Set 13 | half moon bay
# Processing Record 43 of Set 13 | tual
# Processing Record 44 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 45 of Set 13 | komsomolskiy
# Processing Record 46 of Set 13 | fortuna
# Processing Record 47 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 13 | ponta delgada
# Processing Record 49 of Set 13 | namibe
# Processing Record 50 of Set 13 | cabinda
# Processing Record 1 of Set 14 | xuanhua
# Processing Record 2 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 3 of Set 14 | ardakan
# Processing Record 4 of Set 14 | gimli
# Processing Record 5 of Set 14 | javanrud
# Processing Record 6 of Set 14 | viedma
# Processing Record 7 of Set 14 | vangaindrano
# Processing Record 8 of Set 14 | saint anthony
# Processing Record 9 of Set 14 | gigmoto
# Processing Record 10 of Set 14 | miles city
# Processing Record 11 of Set 14 | santa rosa
# Processing Record 12 of Set 14 | santa maria
# Processing Record 13 of Set 14 | jiangkou
# Processing Record 14 of Set 14 | krasnoarmeysk
# Processing Record 15 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 16 of Set 14 | doha
# Processing Record 17 of Set 14 | trincomalee
# Processing Record 18 of Set 14 | prince rupert
# Processing Record 19 of Set 14 | natal
# Processing Record 20 of Set 14 | bayonet point
# Processing Record 21 of Set 14 | el jicaro
# Processing Record 22 of Set 14 | pringsewu
# Processing Record 23 of Set 14 | visby
# Processing Record 24 of Set 14 | san giuseppe jato
# Processing Record 25 of Set 14 | abeche
# Processing Record 26 of Set 14 | raudeberg
# Processing Record 27 of Set 14 | nanning
# Processing Record 28 of Set 14 | inyonga
# Processing Record 29 of Set 14 | uryupinsk
# Processing Record 30 of Set 14 | barabinsk
# Processing Record 31 of Set 14 | zhanaozen
# Processing Record 32 of Set 14 | karpogory
# Processing Record 33 of Set 14 | bjala
# City not found. Skipping...
# Processing Record 34 of Set 14 | pilot butte
# Processing Record 35 of Set 14 | luganville
# Processing Record 36 of Set 14 | aguimes
# Processing Record 37 of Set 14 | limoges
# Processing Record 38 of Set 14 | northam
# Processing Record 39 of Set 14 | shetpe
# Processing Record 40 of Set 14 | panaba
# Processing Record 41 of Set 14 | novosergiyevka
# Processing Record 42 of Set 14 | enshi
# Processing Record 43 of Set 14 | boa vista
# Processing Record 44 of Set 14 | metro
# Processing Record 45 of Set 14 | la ronge
# Processing Record 46 of Set 14 | houma
# Processing Record 47 of Set 14 | ubinskoye
# Processing Record 48 of Set 14 | tazovskiy
# Processing Record 49 of Set 14 | tuatapere
# Processing Record 50 of Set 14 | warman
# Processing Record 1 of Set 15 | fukue
# Processing Record 2 of Set 15 | krasnoselkup
# Processing Record 3 of Set 15 | alice springs
# Processing Record 4 of Set 15 | ler
# Processing Record 5 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 6 of Set 15 | polson
# Processing Record 7 of Set 15 | rawson
# Processing Record 8 of Set 15 | yertarskiy
# Processing Record 9 of Set 15 | labuhan
# Processing Record 10 of Set 15 | san buenaventura
# Processing Record 11 of Set 15 | chinchani
# Processing Record 12 of Set 15 | hope
# Processing Record 13 of Set 15 | roma
# Processing Record 14 of Set 15 | gat
# Processing Record 15 of Set 15 | innisfail
# Processing Record 16 of Set 15 | virginia beach
# Processing Record 17 of Set 15 | oktyabrskiy
# Processing Record 18 of Set 15 | yaan
# Processing Record 19 of Set 15 | vitim
# Processing Record 20 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 15 | grootfontein
# Processing Record 22 of Set 15 | argelia
# Processing Record 23 of Set 15 | sistranda
# Processing Record 24 of Set 15 | kjollefjord
# Processing Record 25 of Set 15 | bluefield
# Processing Record 26 of Set 15 | vila
# Processing Record 27 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 28 of Set 15 | anajatuba
# Processing Record 29 of Set 15 | nhulunbuy
# Processing Record 30 of Set 15 | erenhot
# Processing Record 31 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 15 | port-gentil
# Processing Record 33 of Set 15 | nuuk
# Processing Record 34 of Set 15 | bartica
# Processing Record 35 of Set 15 | phalaborwa
# Processing Record 36 of Set 15 | aliwal north
# Processing Record 37 of Set 15 | noumea
# Processing Record 38 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 40 of Set 15 | bang sai
# Processing Record 41 of Set 15 | cururupu
# Processing Record 42 of Set 15 | george town
# Processing Record 43 of Set 15 | ambon
# Processing Record 44 of Set 15 | kieta
# Processing Record 45 of Set 15 | beisfjord
# Processing Record 46 of Set 15 | coahuayana
# Processing Record 47 of Set 15 | kalmunai
# Processing Record 48 of Set 15 | tadine
# Processing Record 49 of Set 15 | praya
# Processing Record 50 of Set 15 | lusambo
# Processing Record 1 of Set 16 | riyadh
# Processing Record 2 of Set 16 | antsohihy
# Processing Record 3 of Set 16 | monte carmelo
# Processing Record 4 of Set 16 | buchanan
# Processing Record 5 of Set 16 | hofn
# Processing Record 6 of Set 16 | tutoia
# Processing Record 7 of Set 16 | magan
# Processing Record 8 of Set 16 | pemba
# Processing Record 9 of Set 16 | medea
# Processing Record 10 of Set 16 | lubao
# Processing Record 11 of Set 16 | saint combs
# City not found. Skipping...
# Processing Record 12 of Set 16 | kuna
# Processing Record 13 of Set 16 | domoni
# Processing Record 14 of Set 16 | ouro fino
# Processing Record 15 of Set 16 | cascais
# Processing Record 16 of Set 16 | ferrol
# Processing Record 17 of Set 16 | diffa
# Processing Record 18 of Set 16 | chagoda
# Processing Record 19 of Set 16 | elizabeth city
# Processing Record 20 of Set 16 | wolmaranstad
# City not found. Skipping...
# Processing Record 21 of Set 16 | puerto carreno
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %% [markdown]
# ### STEP 7&8 - DF and Export

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Mehamn  71.0357   27.8492     51.31        63           6       12.82
# 1    Ushuaia -54.8000  -68.3000     33.46        75          75       21.85
# 2      Fujin  47.2600  132.0322     76.08        70         100        4.52
# 3   Thompson  55.7435  -97.8558     66.36        77          40        4.61
# 4     Narsaq  60.9167  -46.0500     48.42        93         100        4.34
# 5     Albany  42.6001  -73.9662     67.82        89         100        2.77
# 6  Cape Town -33.9258   18.4232     64.11        47          20       11.50
# 7  Lisakovsk  52.5369   62.4936     64.17        90          90       16.53
# 8  Jamestown  42.0970  -79.2353     67.59        93          75        3.00
# 9       Ziro  27.6333   93.8333     60.33        96          27        0.85
#
#   Country Current Description                 Date
# 0      NO           clear sky  2021-07-11 12:42:41
# 1      AR          light snow  2021-07-11 12:42:41
# 2      CN     overcast clouds  2021-07-11 12:42:41
# 3      CA    scattered clouds  2021-07-11 12:42:42
# 4      GL          light rain  2021-07-11 12:42:42
# 5      US     overcast clouds  2021-07-11 12:41:53
# 6      ZA          few clouds  2021-07-11 12:42:03
# 7      KZ          light rain  2021-07-11 12:42:42
# 8      US       broken clouds  2021-07-11 12:40:55
# 9      IN    scattered clouds  2021-07-11 12:42:42

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed", "Current Description"]
city_data_df= city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Mehamn      NO  71.0357   27.8492     51.31        63
# 1           Ushuaia      AR -54.8000  -68.3000     33.46        75
# 2             Fujin      CN  47.2600  132.0322     76.08        70
# 3          Thompson      CA  55.7435  -97.8558     66.36        77
# 4            Narsaq      GL  60.9167  -46.0500     48.42        93
# ..              ...     ...      ...       ...       ...       ...
# 699          Ferrol      ES  43.4832   -8.2369     70.72        82
# 700           Diffa      NE  13.3154   12.6113     99.34        30
# 701         Chagoda      RU  59.1640   35.3285     88.11        34
# 702  Elizabeth City      US  36.2946  -76.2511     81.99        89
# 703  Puerto Carreno      CO   6.1890  -67.4859     76.86        88
#
#      Cloudiness  Wind Speed Current Description
# 0             6       12.82           clear sky
# 1            75       21.85          light snow
# 2           100        4.52     overcast clouds
# 3            40        4.61    scattered clouds
# 4           100        4.34          light rain
# ..          ...         ...                 ...
# 699         100        6.96     overcast clouds
# 700          89        6.13     overcast clouds
# 701          59        3.44       broken clouds
# 702          75        8.05       broken clouds
# 703         100        2.46     overcast clouds
#
# [704 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
